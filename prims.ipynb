# %%
# generate adjecency matrix
import random

def generateRandomGraph(dimension):
    result = list()
    for i in range(dimension):
        result.append([0] * dimension)
    for i in range(dimension):
        for j in range(i+1,dimension):
            if random.randint(0,1):
                result[i][j] = result[j][i] =random.randint(0,9)
                    
                
                
    return result

adjecencyMatrix = generateRandomGraph(10)

# %%
import networkx as nx
import matplotlib.pyplot as plt

def visualizeGraph(adjMatrix):
    graph = list()
    for i in range(len(adjMatrix)):
        for j in range(i+1,len(adjMatrix)):
            if adjMatrix[i][j] :
                graph.append([i,j])
    G = nx.Graph()
    G.add_edges_from(graph)
    nx.draw_networkx(G)
    plt.show()
    print(graph)

visualizeGraph(adjecencyMatrix)
# Out:
# [[0, 3], [0, 5], [0, 6], [0, 7], [0, 8], [1, 3], [1, 9], [2, 8], [2, 9], [3, 5], [3, 7], [3, 8], [3, 9], [4, 5], [4, 7], [4, 8], [4, 9], [5, 6], [5, 8], [5, 9], [6, 8]]

# %%
def prims(adjMatrix):
    INF = 999
    num = len(adjMatrix)
    selected = [False for i in range(num)]
    edgeCount = 0

    while( edgeCount < num-1):
        minWeight = INF
        
    
    # print (selected)

prims(adjecencyMatrix)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-43-66e9c5880c43> in <module>
#      10     # print (selected)
#      11
# ---> 12 prims(adjecencyMatrix)
#
# <ipython-input-43-66e9c5880c43> in prims(adjMatrix)
#       6
#       7     while( edgeCount < num-1):
# ----> 8         minWeight = INF
#       9
#      10     # print (selected)
#
# KeyboardInterrupt:
